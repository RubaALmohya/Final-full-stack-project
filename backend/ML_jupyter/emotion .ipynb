# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/user/Downloads/womensad.jfif')
print('read image correct')
# Out:
# read image correct

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
predictionImg = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\user\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:01<00:00, 5.54MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\user\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [00:37<00:00, 14.4MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\user\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [03:42<00:00, 2.42MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\user\.deepface\weights\race_model_single_batch.h5
# 100%|██████████| 537M/537M [03:05<00:00, 2.90MB/s]
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 1s/step
# Action: age:  25%|██▌       | 1/4 [00:04<00:12,  4.01s/it]
# 1/1 [==============================] - 2s 2s/step
# Action: gender:  50%|█████     | 2/4 [00:06<00:05,  2.97s/it]
# 1/1 [==============================] - 0s 428ms/step
# Action: race:  75%|███████▌  | 3/4 [00:06<00:01,  1.82s/it]
# 1/1 [==============================] - 0s 367ms/step
# Action: race: 100%|██████████| 4/4 [00:07<00:00,  1.78s/it]

# %%
 predictionImg
# Out:
# {'emotion': {'angry': 4.096069186925888,
#   'disgust': 0.008724290819372982,
#   'fear': 13.441093266010284,
#   'happy': 0.0017124464648077264,
#   'sad': 79.68133091926575,
#   'surprise': 0.0004453324891073862,
#   'neutral': 2.770620584487915},
#  'dominant_emotion': 'sad',
#  'region': {'x': 94, 'y': 32, 'w': 84, 'h': 84},
#  'age': 32,
#  'gender': 'Man',
#  'race': {'asian': 0.23959027603268623,
#   'indian': 4.904220253229141,
#   'black': 0.2865307265892625,
#   'white': 37.28212118148804,
#   'middle eastern': 40.89282155036926,
#   'latino hispanic': 16.394716501235962},
#  'dominant_race': 'middle eastern'}

# %%
 predictionImg['dominant_emotion']
# Out:
# 'sad'
